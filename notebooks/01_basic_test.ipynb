# %%
# Import data
import sys
import numpy as np
sys.path.append('../code')
from minirocket import fit, transform
from sklearn.linear_model import RidgeClassifierCV

# %%
# Load data
from aeon.datasets import load_classification
X_train, y_train = load_classification("GunPoint", split="train")
X_test, y_test = load_classification("GunPoint", split="test")
X_train = X_train.squeeze().astype(np.float32)
X_test = X_test.squeeze().astype(np.float32)
print(f"Train: {X_train.shape}, Test: {X_test.shape}")
# Out:
# Train: (50, 150), Test: (150, 150)

# %%
# Fit and transform the data
import time
t0 = time.time()
parameters = fit(X_train)
X_train_tf = transform(X_train, parameters)
X_test_tf = transform(X_test, parameters)
print(f"Transform time: {time.time() - t0:.2f}s")
print(f"Feature shape: {X_train_tf.shape}")
# Out:
# Transform time: 0.05s
# Feature shape: (50, 9996)

# %%
# Train classifier and evaluate
clf = RidgeClassifierCV(alphas=np.logspace(-3, 3, 10))
clf.fit(X_train_tf, y_train)
acc = clf.score(X_test_tf, y_test)
print(f"Accuracy: {acc:.4f}")
# Out:
# Accuracy: 1.0000
